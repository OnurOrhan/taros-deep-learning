# %%
# !pip install Pillow
from PIL import Image, ImageOps
import numpy as np
import os
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (7.0.0)

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# %cd "gdrive/Shared drives/deep learning"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/Shared drives/deep learning

# %%
images_path  = "./data/images"
images = []
i=0
new_shape = (round(100),round(100))
for root, dirs, files in os.walk(images_path):

  for names in files:

    file_path = os.path.join(root,names)
    im = Image.open(file_path)
    im = ImageOps.grayscale(im)
    im = im.resize(new_shape)

    data = np.array(im)
    
    flattened = data.flatten()
    images.append(flattened.tolist())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-07ae29ab293d> in <module>()
#       8
#       9     file_path = os.path.join(root,names)
# ---> 10     im = Image.open(file_path)
#      11     im = ImageOps.grayscale(im)
#      12     im = im.resize(new_shape)
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2816         exclusive_fp = True
#    2817
# -> 2818     prefix = fp.read(16)
#    2819
#    2820     preinit()
#
# KeyboardInterrupt:
